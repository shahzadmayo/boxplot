# %% [markdown]
# # Boxplot using Seaborn in Python
# ### A box plot helps to maintain the distribution of quantitative data
# ###  The main body of the box plot showing the quartiles and the median’s confidence intervals if enabled

# %%
# import the library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style='whitegrid')
fmri = sns.load_dataset("fmri")

sns.boxplot(x="timepoint",
				y="signal",
				data=fmri)
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %% [markdown]
# ## Basic visualization of “tips” dataset using boxplot

# %%
sns.set(style='whitegrid')
tip = sns.load_dataset('tips')

sns.boxplot(x='day', y='tip', data=tip)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# # Grouping variables in Seaborn boxplot with different attributes
# ## Draw a single horizontal box plot using only one axis:

# %%
# use to set style of background of plot
sns.set(style="whitegrid")

# loading data-set
tip = sns.load_dataset("tips")

sns.boxplot(x =tip['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# # Draw horizontal boxplot:

# %%
# use to set style of background of plot
sns.set(style="whitegrid")

# loading data-set
tip = sns.load_dataset("tips")
sns.boxplot(x ='tip', y ='day', data = tip)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %% [markdown]
# # Using hue parameter

# %%
# use to set style of background of plot
sns.set(style="whitegrid")

# loading data-set
tip = sns.load_dataset("fmri")

sns.boxplot(x ="timepoint",
			y ="signal",
			hue ="region",
			data = fmri)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
# Draw outlines around the data points using linewidth:
# use to set style of background of plot
sns.set(style="whitegrid")

# loading data-set
tip = sns.load_dataset("tips")
sns.boxplot(x = 'day', y = 'tip',
				data = tip,
				linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# ## Draw each level of the hue variable at different locations on the major categorical axis:

# %%
# use to set style of background of plot
sns.set(style="whitegrid")

# loading data-set
tip = sns.load_dataset("tips")
sns.boxplot(x="day", y="total_bill",
				hue="smoker",
				data=tip, palette="Set2",
				dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Control orientation of the plot (vertical or horizontal):

# %%
# use to set style of background of plot
sns.set(style="whitegrid")

# loading data-set
tip = sns.load_dataset("tips")
sns.boxplot(data = tip,orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Using color attributes for Color for all the elements.:

# %%
# use to set style of background of plot
sns.set(style="whitegrid")

# loading data-set
tip = sns.load_dataset("tips")
sns.boxplot(x = 'day', y = 'tip', data = tip,color = "green")

# %% [markdown]
# # Horizontal Boxplots with Seaborn in Python

# %%
df = sns.load_dataset('iris')

# Just switch x and y
sns.boxplot(y=df["species"], x=df["sepal_length"])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %% [markdown]
# # Coloring Boxplots with Palettes

# %%
# load dataset
ds = sns.load_dataset("tips")

plt.figure(figsize=(8, 6))

# use palette method
ax = sns.boxplot(data=ds, orient="h", palette="Set1")

# %% [markdown]
# # How to Show Mean on Boxplot using Seaborn
#
# ### median: the middle value of data. marked as Q2, portrays the 50th percentile.
# ### first quartile: the middle value between “minimum non-outlier” and median. marked as Q1, portrays the 25th percentile.
# ### third quartile: the middle value between “maximum non-outlier” and median. marked as Q3, portrays the 75th percentile.
# ### “maximum non-outlier”: calculated by (Q3 + 1.5*IQR). All values above this are considered outliers.
# ### “minimum non-outlier”: calculated by (Q1 – 1.5*IQR). All values below this are considered outliers.

# %%
# importing useful libraries
import seaborn as sns
import matplotlib.pyplot as plt

# using titanic dataset from
# seaborn library
df = sns.load_dataset("titanic")

# to see first 5 rows of dataset
print(df.head())
# age vs survived feature
plt.figure(figsize=(10, 8))
sns.boxplot(x='survived',
			y='age',
			data=df)
plt.ylabel("Age", size=14)
plt.xlabel("Survived", size=14)
plt.title("Titanic Dataset", size=18)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# Text(0.5, 1.0, 'Titanic Dataset')

# %%
# customizing using meanprops
plt.figure(figsize=(10, 8))
sns.boxplot(x='survived',
			y='age',
			data=df,
			showmeans=True,
			meanprops={"marker": "+",
					"markeredgecolor": "black",
					"markersize": "10"})
plt.ylabel("Age", size=14)
plt.xlabel("Survived", size=14)
plt.title("Titanic Dataset", size=18)
# Out:
# Text(0.5, 1.0, 'Titanic Dataset')

# %%
# load dataset
tips = sns.load_dataset('tips')


# display top most rows
tips.head()


# plotting the boxplot taking time on x-axis
fx = sns.boxplot(x="time", y="total_bill", hue="smoker",
				data=tips, palette="Set1")

# %%
# illustrating box plot with order
ax = sns.boxplot(x="time", y="total_bill", hue="smoker", order=['Dinner', 'Lunch'],
				data=tips, palette="Set1")

# %% [markdown]
# # Grouped Boxplots in Python with Seaborn
# ## Boxplots consist of a five-number summary which helps in detecting and removing outliers from the dataset.
#
# ### Minimum observation
# ### Q1 (25% or Quartile 1)
# ### Median or Q2
# ### Q3 (75% or Quartile 2)
# ### Maximum Observation

# %%
# import seaborn library
import seaborn as sns

# load the dataset
data = sns.load_dataset('tips')

# create grouped boxplot
sns.boxplot(x = data['day'],
			y = data['total_bill'],
			hue = data['sex'])
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# create another grouped boxplot
sns.boxplot(x = data['day'],
			y = data['total_bill'],
			hue = data['smoker'],
			palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# create 3rd grouped boxplot
sns.boxplot(x = data['day'],
			y = data['total_bill'],
			hue = data['size'],
			palette = 'husl')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Box plot visualization with Pandas and Seaborn
# ## Draw the box plot with Pandas:

# %%
# load the dataset
df =sns.load_dataset("tips")
df.boxplot(by ='day', column =['total_bill'], grid = False)
# Out:
# <AxesSubplot:title={'center':'total_bill'}, xlabel='day'>

# %%
df.boxplot(by ='size', column =['tip'], grid = False)
# Out:
# <AxesSubplot:title={'center':'tip'}, xlabel='size'>

# %%
sns.set_style("whitegrid")
  
sns.boxplot(x = 'day', y = 'total_bill', data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
